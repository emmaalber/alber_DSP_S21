# %% [markdown]
# ## Homework 2: Data structures and data cleaning
#
# [VP] - on time and full credit
#
# In this homework you will have to apply the knowledge you have learned about tidy data from reading Wickham (2014). You will have to identify problems with the organization of example datasets using the terms introduced in Wickham. You will also have to tidy a dataset, and perform some basic cleaning operations.
#
# Before you begin, you will need to have completed the following requirements:
# - Read Wickham (2014)
# - If you haven't worked with the tidyverse package before, you need to install it with the `install.packages('tidyverse')` command
# - Consult Tutorial 2, which explains the basic tidyverse commands for processing data: https://github.com/venpopov/DataSciencePsychUZH/blob/main/Tutorials/Tutorial02_Data_processing_with_R_and_tidyverse.ipynb
#
# *Copy this notebook, the folder `data` and the folder `figures` in your repository, and type in your responses and/or code in the corresponding cells. Your homework will be scored based on the total number of points (30 total possible).*
#
# Clarification: to copy the relevant files into your repository, you first need to download them to your computer. You can do that one of two ways. First, you can open a terminal and type `git clone https://github.com/venpopov/DataSciencePsychUZH`. This will copy the entire class repository on your local computer. Then you can locate the homework2 notebook, and the data/figures folders. Then you can copy and paste them into your own repository.
#
# Alternatively, you can directly download all files from the repository by going to the main repository page on your browser and clicking on `Code > Download ZIP` as shown in the image below. This will download all repository files into a ZIP archive on your computer. Extract the files from the archive into a new folder. Then copy and paste the homework2 notebook, and the data/figures folders into your repository.
#
# ![image.png](attachment:image.png)

# %%
install.packages('tidyverse')
library(tidyverse)
install.packages('dplyr')
library(dplyr)
# Out:
# The downloaded binary packages are in
# 	/var/folders/3n/g4p4960s3wx9bqgjvhfjz07c0000gn/T//Rtmp4iQhEG/downloaded_packages
#
# The downloaded binary packages are in
# 	/var/folders/3n/g4p4960s3wx9bqgjvhfjz07c0000gn/T//Rtmp4iQhEG/downloaded_packages

# %% [markdown]
# ### 1. Identifying non-tidy datasets

# %% [markdown]
# #### 1.1 Problem 1
# The dataset below shows demographic information, IQ and college grade point average for several students

# %%
iq_grade <- read.csv('/Users/Emma/Desktop/data/iq_grade.csv')
iq_grade
# Out:
#   subject_id demographic_info verbal_IQ GPA
# 1 101        male, 23         105       3.9
# 2 102        male, 19         121       3.2
# 3 103        female, 27       123       3.4
# 4 104        male, 21          97       2.8
# 5 105        female, 21        93       2.9
# 6 106        female, 25       135       3.8

# %% [markdown]
# > [VP] - please use relative file paths in the future (e.g., 'data/iq_grade.csv')

# %% [markdown]
# This dataset is not in a tidy format. Why? Which of the five most common problems described by Wickhams is this an example of? Edit this cell and replace the text below with your response **(1 point)**:
#
# > There are multiple variables stored in the column "demographic_info": gender (or sex) and age. They should be split.

# %% [markdown]
# What would you have to do to make this dataset in tidy format? **(1 point)**
# > I would have to split the column "demographic_info" into two variables: sex and age.

# %% [markdown]
# Write code in the cell below to transform the `iq_grades` table into tidy format
#
# (hint: use the separate() command from the tidyverse package - see Tutorial 2; **3 points**):

# %%
dat <- iq_grade  %>% 
    separate(demographic_info, into=c('sex', 'age')) 
head(dat)
# Out:
#   subject_id sex    age verbal_IQ GPA
# 1 101        male   23  105       3.9
# 2 102        male   19  121       3.2
# 3 103        female 27  123       3.4
# 4 104        male   21   97       2.8
# 5 105        female 21   93       2.9
# 6 106        female 25  135       3.8

# %% [markdown]
# #### 1.2 Problem 2
# The dataset below shows statistics about violent crime rates by US state. The numbers represent frequency per 100,000 people.

# %%
suppressMessages(library(tidyverse))

data("USArrests")
USArrests <- select(USArrests, -UrbanPop)
head(USArrests)
# Out:
#            Murder Assault Rape
# Alabama    13.2   236     21.2
# Alaska     10.0   263     44.5
# Arizona     8.1   294     31.0
# Arkansas    8.8   190     19.5
# California  9.0   276     40.6
# Colorado    7.9   204     38.7

# %% [markdown]
# This dataset is not in a tidy format. Why? Which of the five most common problems described by Wickhams is this an example of? Edit this cell and replace the text below with your response **(1 point)**:
#
# > The variables are stored in both rows and columns - in order to achieve tidy data, the states are variables and should be put into a column, not a row.

# %% [markdown]
# What would you have to do to make this dataset in tidy format? **(1 point)**
# > I'd have to melt the dataset and create a column with the states with the added hearder "states".

# %% [markdown]
# Write code in the cell below to transform the `USArrests` table into tidy format
#
# (hint: use the gather() command from the tidyverse package - see Tutorial 2; **3 points**):

# %%
newarrests <- USArrests #duplicate the USArrests file
head(newarrests)
nrow(newarrests) #find out how many states there are in this table
# Out:
#            Murder Assault Rape
# Alabama    13.2   236     21.2
# Alaska     10.0   263     44.5
# Arizona     8.1   294     31.0
# Arkansas    8.8   190     19.5
# California  9.0   276     40.6
# Colorado    7.9   204     38.7
# [1] 50

# %%
newarrests <- newarrests %>% 
       mutate(state = rownames(newarrests)) #create new variable called "state"
newarrests
# Out:
#                Murder Assault Rape state
# Alabama        13.2   236     21.2 Alabama
# Alaska         10.0   263     44.5 Alaska
# Arizona         8.1   294     31.0 Arizona
# Arkansas        8.8   190     19.5 Arkansas
# California      9.0   276     40.6 California
# Colorado        7.9   204     38.7 Colorado
# Connecticut     3.3   110     11.1 Connecticut
# Delaware        5.9   238     15.8 Delaware
# Florida        15.4   335     31.9 Florida
# Georgia        17.4   211     25.8 Georgia
# Hawaii          5.3    46     20.2 Hawaii
# Idaho           2.6   120     14.2 Idaho
# Illinois       10.4   249     24.0 Illinois
# Indiana         7.2   113     21.0 Indiana
# Iowa            2.2    56     11.3 Iowa
# Kansas          6.0   115     18.0 Kansas
# Kentucky        9.7   109     16.3 Kentucky
# Louisiana      15.4   249     22.2 Louisiana
# Maine           2.1    83      7.8 Maine
# Maryland       11.3   300     27.8 Maryland
# Massachusetts   4.4   149     16.3 Massachusetts
# Michigan       12.1   255     35.1 Michigan
# Minnesota       2.7    72     14.9 Minnesota
# Mississippi    16.1   259     17.1 Mississippi
# Missouri        9.0   178     28.2 Missouri
# Montana         6.0   109     16.4 Montana
# Nebraska        4.3   102     16.5 Nebraska
# Nevada         12.2   252     46.0 Nevada
# New Hampshire   2.1    57      9.5 New Hampshire
# New Jersey      7.4   159     18.8 New Jersey
# New Mexico     11.4   285     32.1 New Mexico
# New York       11.1   254     26.1 New York
# North Carolina 13.0   337     16.1 North Carolina
# North Dakota    0.8    45      7.3 North Dakota
# Ohio            7.3   120     21.4 Ohio
# Oklahoma        6.6   151     20.0 Oklahoma
# Oregon          4.9   159     29.3 Oregon
# Pennsylvania    6.3   106     14.9 Pennsylvania
# Rhode Island    3.4   174      8.3 Rhode Island
# South Carolina 14.4   279     22.5 South Carolina
# South Dakota    3.8    86     12.8 South Dakota
# Tennessee      13.2   188     26.9 Tennessee
# Texas          12.7   201     25.5 Texas
# Utah            3.2   120     22.9 Utah
# Vermont         2.2    48     11.2 Vermont
# Virginia        8.5   156     20.7 Virginia
# Washington      4.0   145     26.2 Washington
# West Virginia   5.7    81      9.3 West Virginia
# Wisconsin       2.6    53     10.8 Wisconsin
# Wyoming         6.8   161     15.6 Wyoming

# %%
newarrests <- newarrests %>%
    gather(key=crime, value="freq_per_100k", Murder:Rape) #turn into long format by stacking the crimes

newarrests
# Out:
#     state          crime  freq_per_100k
# 1   Alabama        Murder 13.2
# 2   Alaska         Murder 10.0
# 3   Arizona        Murder  8.1
# 4   Arkansas       Murder  8.8
# 5   California     Murder  9.0
# 6   Colorado       Murder  7.9
# 7   Connecticut    Murder  3.3
# 8   Delaware       Murder  5.9
# 9   Florida        Murder 15.4
# 10  Georgia        Murder 17.4
# 11  Hawaii         Murder  5.3
# 12  Idaho          Murder  2.6
# 13  Illinois       Murder 10.4
# 14  Indiana        Murder  7.2
# 15  Iowa           Murder  2.2
# 16  Kansas         Murder  6.0
# 17  Kentucky       Murder  9.7
# 18  Louisiana      Murder 15.4
# 19  Maine          Murder  2.1
# 20  Maryland       Murder 11.3
# 21  Massachusetts  Murder  4.4
# 22  Michigan       Murder 12.1
# 23  Minnesota      Murder  2.7
# 24  Mississippi    Murder 16.1
# 25  Missouri       Murder  9.0
# 26  Montana        Murder  6.0
# 27  Nebraska       Murder  4.3
# 28  Nevada         Murder 12.2
# 29  New Hampshire  Murder  2.1
# 30  New Jersey     Murder  7.4
# ⋮   ⋮              ⋮      ⋮
# 121 Massachusetts  Rape   16.3
# 122 Michigan       Rape   35.1
# 123 Minnesota      Rape   14.9
# 124 Mississippi    Rape   17.1
# 125 Missouri       Rape   28.2
# 126 Montana        Rape   16.4
# 127 Nebraska       Rape   16.5
# 128 Nevada         Rape   46.0
# 129 New Hampshire  Rape    9.5
# 130 New Jersey     Rape   18.8
# 131 New Mexico     Rape   32.1
# 132 New York       Rape   26.1
# 133 North Carolina Rape   16.1
# 134 North Dakota   Rape    7.3
# 135 Ohio           Rape   21.4
# 136 Oklahoma       Rape   20.0
# 137 Oregon         Rape   29.3
# 138 Pennsylvania   Rape   14.9
# 139 Rhode Island   Rape    8.3
# 140 South Carolina Rape   22.5
# 141 South Dakota   Rape   12.8
# 142 Tennessee      Rape   26.9
# 143 Texas          Rape   25.5
# 144 Utah           Rape   22.9
# 145 Vermont        Rape   11.2
# 146 Virginia       Rape   20.7
# 147 Washington     Rape   26.2
# 148 West Virginia  Rape    9.3
# 149 Wisconsin      Rape   10.8
# 150 Wyoming        Rape   15.6

# %% [markdown]
# #### 1.3 Problem 3

# %% [markdown]
# The three tables below give the measurements in centimeters of the variables sepal length, sepal width, petal length and petal width, respectively, for 50 flowers from each of 3 species of iris flowers. The species are setosa, versicolor, and virginica.

# %%
# load data
setosa <- read.csv('data/setosa.csv')
virginica <- read.csv('data/virginica.csv')
versicolor <- read.csv('data/versicolor.csv')

# look at the data
head(setosa)
head(virginica)
head(versicolor)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 5.1          3.5         1.4          0.2
# 2 4.9          3.0         1.4          0.2
# 3 4.7          3.2         1.3          0.2
# 4 4.6          3.1         1.5          0.2
# 5 5.0          3.6         1.4          0.2
# 6 5.4          3.9         1.7          0.4
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 6.3          3.3         6.0          2.5
# 2 5.8          2.7         5.1          1.9
# 3 7.1          3.0         5.9          2.1
# 4 6.3          2.9         5.6          1.8
# 5 6.5          3.0         5.8          2.2
# 6 7.6          3.0         6.6          2.1
#   Sepal.Length Sepal.Width Petal.Length Petal.Width
# 1 7.0          3.2         4.7          1.4
# 2 6.4          3.2         4.5          1.5
# 3 6.9          3.1         4.9          1.5
# 4 5.5          2.3         4.0          1.3
# 5 6.5          2.8         4.6          1.5
# 6 5.7          2.8         4.5          1.3

# %% [markdown]
# These tables are not in tidy format. Why? Which of the five most common problems described by Wickhams is this an example of? Edit this cell and replace the text below with your response **(1 point)**:
# > There is the same type of observational unit in all three tables (the four variables are all the sam ein all three datasets). Wickham writes that they should be combined in one single table, with the addition of a column recording which file they came from. Like this, we can still see which species it is.

# %% [markdown]
# What would you have to do to make this dataset in tidy format? **(1 point)**
# > Read the files into a list of tables. For each table, add a new column that records the original file name (here, the species). Combine all tables into a single table. Wickham writes that this can be easily done with the plyr package.

# %% [markdown]
# Write code in the cell below to transform the `setosa`, `virginica` and `versicolor` tables into tidy format
#
# (hint: use the `bind_rows()` command from the tidyverse package; remember to include information about the species in tidy dataset; **3 points**):

# %%
setosa$iris <- "setosa"
virginica$iris <- "virginica"
versicolor$iris <- "versicolor" # assign a new column to each table with the name of the species
head(setosa)
head(virginica)
head(versicolor) #check if the new column is there
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width iris
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
#   Sepal.Length Sepal.Width Petal.Length Petal.Width iris
# 1 6.3          3.3         6.0          2.5         virginica
# 2 5.8          2.7         5.1          1.9         virginica
# 3 7.1          3.0         5.9          2.1         virginica
# 4 6.3          2.9         5.6          1.8         virginica
# 5 6.5          3.0         5.8          2.2         virginica
# 6 7.6          3.0         6.6          2.1         virginica
#   Sepal.Length Sepal.Width Petal.Length Petal.Width iris
# 1 7.0          3.2         4.7          1.4         versicolor
# 2 6.4          3.2         4.5          1.5         versicolor
# 3 6.9          3.1         4.9          1.5         versicolor
# 4 5.5          2.3         4.0          1.3         versicolor
# 5 6.5          2.8         4.6          1.5         versicolor
# 6 5.7          2.8         4.5          1.3         versicolor

# %%
fulliris <- bind_rows(setosa, virginica, versicolor) # put the three tables in one single table
head(fulliris) # look at the table
nrow(fulliris) #check if I got all of them
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width iris
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa
# [1] 150

# %% [markdown]
# ### 2. Putting it all together

# %% [markdown]
# The files `basel_weather_2018.csv`, `basel_weather_2019.csv`, `basel_weather_2020.csv` in the folder `data` contain detailed information about the minimum, mean and maximum temperature in Basel, Switzerland for every hour of every day of the last three years.
#
# The datasets have multiple structural issues. Combine your knowledge from the previous 3 problems to transform these datasets into a tidy format. The tidy format should allow you at the end to produce two plots:
# 1. average mean temperature as a function of a time of day
# 2. average maximum temperature as a function of month
#
# When you are done, you should be able to produce the following two plots:
#
# ![max_temperature_plot](figures/basel_temp_by_month.png)
# ![mean_temperature_plot](figures/basel_temp_by_time_of_day.png)

# %% [markdown]
# First load the three dataset into three separate variables **(1 point)**:

# %%
w2018 <- read.csv('/Users/Emma/Desktop/data/basel_weather_2018.csv')
w2019 <- read.csv('/Users/Emma/Desktop/data/basel_weather_2019.csv')
w2020 <- read.csv('/Users/Emma/Desktop/data/basel_weather_2020.csv')

# %% [markdown]
# Use the `head()` command to take a look at the first few rows of each dataset **(1 point)**:

# %%
head(w2018)
head(w2019)
head(w2020)
# Out:
#   timestamp     temperature_type temperature
# 1 20180101T0000 temperature_mean 10.500529
# 2 20180101T0000 temperature_min   7.500529
# 3 20180101T0000 temperature_max  15.500529
# 4 20180101T0100 temperature_mean  9.790529
# 5 20180101T0100 temperature_min   5.790529
# 6 20180101T0100 temperature_max  13.790529
#   timestamp     temperature_type temperature
# 1 20190101T0000 temperature_mean 5.0505285
# 2 20190101T0000 temperature_min  0.0505285
# 3 20190101T0000 temperature_max  9.0505285
# 4 20190101T0100 temperature_mean 4.9005284
# 5 20190101T0100 temperature_min  2.9005284
# 6 20190101T0100 temperature_max  8.9005284
#   timestamp     temperature_type temperature
# 1 20200101T0000 temperature_mean 1.4905287
# 2 20200101T0000 temperature_min  0.4905287
# 3 20200101T0000 temperature_max  3.4905287
# 4 20200101T0100 temperature_mean 1.6905286
# 5 20200101T0100 temperature_min  0.6905286
# 6 20200101T0100 temperature_max  6.6905286

# %% [markdown]
# Use the `bind_rows()` command to combine the three datasets into one **(1 point)**:

# %%
fullweather <- bind_rows(w2018, w2019, w2020) # put the three tables in one single table
head(fullweather) # look at the table
nrow(fullweather) #check if I got all of them #woah it's many
# Out:
#   timestamp     temperature_type temperature
# 1 20180101T0000 temperature_mean 10.500529
# 2 20180101T0000 temperature_min   7.500529
# 3 20180101T0000 temperature_max  15.500529
# 4 20180101T0100 temperature_mean  9.790529
# 5 20180101T0100 temperature_min   5.790529
# 6 20180101T0100 temperature_max  13.790529
# [1] 78912

# %% [markdown]
# Use the `spread()` command to transform the dataset such that the mean, maximum, and minimum temperatures are in separate columns **(2 points)**:

# %%
fullweather_temp <- fullweather %>% spread(key = temperature_type, value = temperature)
head(fullweather_temp)
# Out:
#   timestamp     year month day hour temperature_max temperature_mean
# 1 20180101T0000 2018 01    01  0000 15.500529       10.500529
# 2 20180101T0100 2018 01    01  0100 13.790529        9.790529
# 3 20180101T0200 2018 01    01  0200  9.970529        8.970529
# 4 20180101T0300 2018 01    01  0300 11.690529        8.690529
# 5 20180101T0400 2018 01    01  0400 11.960528        7.960528
# 6 20180101T0500 2018 01    01  0500  9.360528        7.360529
#   temperature_min
# 1 7.500529
# 2 5.790529
# 3 6.970529
# 4 5.690529
# 5 6.960528
# 6 3.360529

# %% [markdown]
# The variable `timestamp` contains in each row a single string that represents the year, month, day and time of day in a single value. For example, `20200708T0700` means that the temperature in this row was observed on July 8th, 2020 at 7am. Create four new columns in your combined dataset:
# - Year
# - Month
# - Day
# - Hour
#
# and use the `substr()` command to extract the relevant information for each column from the `timestamp` variable. For example, `substr(temp_data$timestamp, 7, 8)` would extract the day from the timestamp.
#
# If you need help understanding the `substr()` command, [read this](https://stat.ethz.ch/R-manual/R-devel/library/base/html/substr.html)  **(2 points)**:

# %%
fullweather_temp$year <- substr(fullweather_temp$timestamp, 1, 4)
fullweather_temp$month <- substr(fullweather_temp$timestamp, 5, 6)
fullweather_temp$day <- substr(fullweather_temp$timestamp, 7, 8) 
fullweather_temp$hour <- substr(fullweather_temp$timestamp, 10, 13) # extract and fill four columns with the correct title

head(fullweather_temp) # check if they're here
# Out:
#   timestamp     year month day hour temperature_max temperature_mean
# 1 20180101T0000 2018 01    01  0000 15.500529       10.500529
# 2 20180101T0100 2018 01    01  0100 13.790529        9.790529
# 3 20180101T0200 2018 01    01  0200  9.970529        8.970529
# 4 20180101T0300 2018 01    01  0300 11.690529        8.690529
# 5 20180101T0400 2018 01    01  0400 11.960528        7.960528
# 6 20180101T0500 2018 01    01  0500  9.360528        7.360529
#   temperature_min
# 1 7.500529
# 2 5.790529
# 3 6.970529
# 4 5.690529
# 5 6.960528
# 6 3.360529

# %% [markdown]
# > [VP] - you can use "mutate()" to avoid writing the `fullweather_temp` every time

# %% [markdown]
# Create a new dataset `monthly_temp` using the `group_by()` and `summarise()` commands (see Tutorial 2, Section 5). The new dataset should contain the average maximum temperature for each month. It should have 12 rows and two variables - `month` and `max_temperature`. **(2 points)**

# %%
monthly_temp <- fullweather_temp # assign new name to new dataset
head(monthly_temp)
# Out:
#   timestamp     year month day hour temperature_max temperature_mean
# 1 20180101T0000 2018 01    01  0000 15.500529       10.500529
# 2 20180101T0100 2018 01    01  0100 13.790529        9.790529
# 3 20180101T0200 2018 01    01  0200  9.970529        8.970529
# 4 20180101T0300 2018 01    01  0300 11.690529        8.690529
# 5 20180101T0400 2018 01    01  0400 11.960528        7.960528
# 6 20180101T0500 2018 01    01  0500  9.360528        7.360529
#   temperature_min
# 1 7.500529
# 2 5.790529
# 3 6.970529
# 4 5.690529
# 5 6.960528
# 6 3.360529

# %%
mean_temp <- monthly_temp  %>% # assign new name far dataframe
    group_by(month)  %>% # implicitly group by the variable "month"
    summarise(temperature_max = mean(temperature_max)) # get a summary of the mean max temp per month
mean_temp
# Out:
#    month temperature_max
# 1  01     7.891313
# 2  02     8.284421
# 3  03    10.869633
# 4  04    16.536487
# 5  05    18.150847
# 6  06    22.937376
# 7  07    25.177438
# 8  08    25.101542
# 9  09    21.215122
# 10 10    16.321228
# 11 11    11.292895
# 12 12     8.683298

# %% [markdown]
# Use the `ggplot()` command on your newly created `monthly_temp` summarized dataset to reproduce the first plot above. The x axis should show the month, and the y axis should show the average maximum temperature for each month. **(2 points)**

# %%
install.packages("ggplot2")
library(ggplot2) # install the needed package
# Out:
# The downloaded binary packages are in
# 	/var/folders/3n/g4p4960s3wx9bqgjvhfjz07c0000gn/T//Rtmp7PMmJd/downloaded_packages

# %%
ggplot(mean_temp, aes(x = month, y =temperature_max))+  geom_point() # can't figute out how to make a line
# Out:
# plot without title

# %% [markdown]
# Create a new dataset `hourly_temp` using the `group_by()` and `summarise()` commands. The new dataset should contain the average mean temperature for each hour. It should have 24 rows and two variables - `hour` and `mean_temperature`. **(2 points)**

# %%
hourly_temp <- fullweather_temp # assign new name to new dataset
 
mean_hourly_temp <- hourly_temp  %>% 
    group_by(hour)  %>%  # implicitly group by the variable "hour"
    summarise(temperature_max = mean(temperature_max))
mean_hourly_temp
# Out:
#    hour temperature_max
# 1  0000 14.32400
# 2  0100 13.88461
# 3  0200 13.52880
# 4  0300 13.12617
# 5  0400 12.78611
# 6  0500 12.63703
# 7  0600 12.49153
# 8  0700 12.85701
# 9  0800 13.66390
# 10 0900 14.99167
# 11 1000 16.26691
# 12 1100 17.56139
# 13 1200 18.56672
# 14 1300 19.35894
# 15 1400 19.75540
# 16 1500 20.02091
# 17 1600 19.86221
# 18 1700 19.43771
# 19 1800 18.83943
# 20 1900 18.09689
# 21 2000 17.08495
# 22 2100 16.24680
# 23 2200 15.51518
# 24 2300 14.86307

# %% [markdown]
# Use the `ggplot()` command on your newly created `hourly_temp` summarized dataset to reproduce the second plot above. The x axis should show the time of day (hour), and the y axis should show the average mean temperature for each time of day. **(2 points)**

# %%
ggplot(mean_hourly_temp, aes(x = hour, y =temperature_max))+  geom_point() # still can't figute out how to make a line
# Out:
# plot without title
